# %%
from models import Model
from extraUtils.misc import count_params

from configs import  filters
encoder = Model()

# %%
count_params(encoder)
# Out:
# =============================================
# Model Parameter Summary
# =============================================
# encoder                  : 157,216
# mapping_net              : 78,592
# pcinr                    : 49,921
# ---------------------------------------------
# Total Trainable Params   : 285,729
# =============================================
# 285729

# %%
from encodec.msstftd import MultiScaleSTFTDiscriminator
discriminator = MultiScaleSTFTDiscriminator(
    filters= filters
)
count_params(discriminator)
# Out:
# =============================================
# Model Parameter Summary
# =============================================
# discriminators           : 217,734
# ---------------------------------------------
# Total Trainable Params   : 217,734
# =============================================
# e:\programs\AudioSuperresolution\.venv\Lib\site-packages\torch\nn\utils\weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# 217734
