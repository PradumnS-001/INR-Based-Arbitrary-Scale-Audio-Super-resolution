# %%
from models import Encoder, INRDecoder
from extraUtils.misc import count_params

encoder = Encoder()
decoder = INRDecoder()

# %%
count_params(decoder)
count_params(encoder)
# Out:
# =============================================
# Model Parameter Summary
# =============================================
# decoder                  : 412,581
# ---------------------------------------------
# Total Trainable Params   : 412,581
# =============================================
#
#
# =============================================
# Model Parameter Summary
# =============================================
# trunc                    : 7,904
# mean_head                : 14,432
# std_head                 : 14,432
# ---------------------------------------------
# Total Trainable Params   : 36,768
# =============================================
# 36768

# %%
from encodec.msstftd import MultiScaleSTFTDiscriminator
discriminator = MultiScaleSTFTDiscriminator(
    filters= 22,
    n_ffts=[2048,512,128]
)
count_params(discriminator)
# Out:
# =============================================
# Model Parameter Summary
# =============================================
# discriminators           : 135,438
# ---------------------------------------------
# Total Trainable Params   : 135,438
# =============================================
# 135438
